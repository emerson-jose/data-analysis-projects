# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-jose/data-analysis-projects/blob/main/TRATAMENTO_DE_DADOS_CLIENTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPOTANCAO DAS BIBLIOTECAS

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#CARREGAMENTO DO ARQUIVO QUE SERA ANALIZADO
df=pd.read_csv('/content/Clientes.csv')

# %%
df.head(4)
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# 3                                     NaN     NaN          NaN

# %%
#VISUALIANDO INFORMACOES SOBRE O DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           100 non-null    int64
#  1   created_at   100 non-null    object
#  2   first_name   100 non-null    object
#  3   last_name    100 non-null    object
#  4   email        85 non-null     object
#  5   cell_phone   100 non-null    object
#  6   country      100 non-null    object
#  7   state        96 non-null     object
#  8   street       85 non-null     object
#  9   number       85 non-null     float64
#  10  additionals  66 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 8.7+ KB

# %%
#VISUALIZANDO A DIMENSAO DO DF
df.shape
# Out:
# (100, 11)

# %%
#IREI DETERMINAR UMA COLUNA DO DF PARA  SER INDICE NO CASO O (ID)
df.set_index('id')
# Out:
#              created_at first_name last_name                 email  \
# id
# 0   2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1   2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2   2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3   2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4   2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..                  ...        ...       ...                   ...
# 95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# id
# 0   9 9102-7834  Brasil               Acre
# 1   9 7328-8718  Brasil  Rio Grande do Sul
# 2   9 5906-7552  Brasil          São Paulo
# 3   9 4642-9486  Brasil        Mato Grosso
# 4   9 3093-6522  Brasil              Bahia
# ..          ...     ...                ...
# 95  9 3139-2145  Brasil                NaN
# 96  9 4785-1135  Brasil            Sergipe
# 97  9 4102-4352  Brasil             Paraná
# 98  9 4211-6968  Brasil        Mato Grosso
# 99  9 6100-1466  Brasil             Paraná
#
#                                     street  number  additionals
# id
# 0                                      NaN     NaN  Conjunto 16
# 1   Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2           Avenida 59 do Estado São Paulo   534.0          NaN
# 3                                      NaN     NaN          NaN
# 4                 Praça 56 do Estado Bahia   191.0      Apto 12
# ..                                     ...     ...          ...
# 95                                     NaN     NaN          NaN
# 96              Praça 73 do Estado Sergipe   219.0       Apto 6
# 97                 Rua 61 do Estado Paraná   402.0      Apto 24
# 98          Praça 75 do Estado Mato Grosso    24.0          NaN
# 99             Avenida 19 do Estado Paraná   738.0  Conjunto 22
#
# [100 rows x 10 columns]

# %%
# ANTES DE COMECAR O TRATAMENTO IREI TROCAR  O NOME DAS COLUNAS MAS ANTES VOU  VISUALIZA-LAS
df.columns
# Out:
# Index(['id', 'created_at', 'first_name', 'last_name', 'email', 'cell_phone',
#        'country', 'state', 'street', 'number', 'additionals'],
#       dtype='object')

# %%
#RENOMEANDO NOMES DAS COLUNAS

df = df.rename(columns={'id':'cod','created_at':'data_de_criação',
'first_name':'NOME', 'last_name':'SOBRE_NOME',
'email':'GMAIL', 'cell_phone':'NUM_CONTATO','country':'PAIS', 'state':
'ESTADO', 'street':'RUA','number':'NUMERO', 'additionals':'ADICIONAIS'})

# %%
#VISUALISANDO NOVAMENTE O NOME DAS COLUNAS
df.columns
# Out:
# Index(['cod', 'data_de_criação', 'NOME', 'SOBRE_NOME', 'GMAIL', 'NUM_CONTATO',
#        'PAIS', 'ESTADO', 'RUA', 'NUMERO', 'ADICIONAIS'],
#       dtype='object')

# %%
# ANTES DE TRATAR VALORES NULOS VOU DEIXAR NOME DAS COLUNAS EM CAIXA BAIXA
df.columns=df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod              100 non-null    int64
#  1   data_de_criação  100 non-null    object
#  2   nome             100 non-null    object
#  3   sobre_nome       100 non-null    object
#  4   gmail            85 non-null     object
#  5   num_contato      100 non-null    object
#  6   pais             100 non-null    object
#  7   estado           96 non-null     object
#  8   rua              85 non-null     object
#  9   numero           85 non-null     float64
#  10  adicionais       66 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 8.7+ KB

# %%
#AGORA  TRATAR VALORES NULOS

df.isna().sum()
# Out:
# cod                 0
# data_de_criação     0
# nome                0
# sobre_nome          0
# gmail              15
# num_contato         0
# pais                0
# estado              4
# rua                15
# numero             15
# adicionais         34
# dtype: int64

# %%
# TRATANDO VALORES NAN OU NUL
# TEMOS 5 COLUNAS COM VALORES NULOS

df['gmail'] = df['gmail'].fillna('NAO_INFORMADO')

df['estado']= df['estado'].fillna('NAO_INFORMADO')

df['rua'] = df['rua'].fillna('NAO_INFORMADA')

df['numero'] = df['numero'].fillna(0)

df['adicionais'] =df['adicionais'].fillna('SEM_ADICIONAL')

# %%
#visualizar mais uma vez para ver houve o tratamente

df.isna().sum()
# Out:
# cod                0
# data_de_criação    0
# nome               0
# sobre_nome         0
# gmail              0
# num_contato        0
# pais               0
# estado             0
# rua                0
# numero             0
# adicionais         0
# dtype: int64

# %%
#CONTANDO OCORRENCIAS DISTINTAS NAS COLUNAS
df.nunique()
# Out:
# cod                100
# data_de_criação    100
# nome                47
# sobre_nome          47
# gmail               71
# num_contato        100
# pais                 1
# estado              26
# rua                 86
# numero              81
# adicionais          37
# dtype: int64

# %%
df.head(10)
# Out:
#    cod      data_de_criação       nome sobre_nome                  gmail  \
# 0    0  2017-11-01 14:45:41      Marta      Jesus          NAO_INFORMADO
# 1    1  2017-10-16 00:50:39      Luana    Almeida          NAO_INFORMADO
# 2    2  2018-06-16 17:51:29      Frida     Mendes    frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela    Avelino    daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário   Teixeira          NAO_INFORMADO
# 5    5  2018-01-05 17:20:49    Marcelo    Barroso          NAO_INFORMADO
# 6    6  2018-06-18 11:17:42  Cristiano     Elísio  cristiano@exemplo.com
# 7    7  2018-02-08 12:36:09    Everton    Barbosa  everton@meu_email.com
# 8    8  2017-12-16 20:47:03   Gabriela      Alves   gabriela@exemplo.com
# 9    9  2018-11-11 11:48:41       Luan       Dias       luan@exemplo.com
#
#    num_contato    pais             estado  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
# 5  9 2830-2088  Brasil  Rio Grande do Sul
# 6  9 3532-8404  Brasil              Goiás
# 7  9 2553-4087  Brasil   Distrito Federal
# 8  9 1353-8433  Brasil     Santa Catarina
# 9  9 2417-3678  Brasil   Distrito Federal
#
#                                       rua  numero     adicionais
# 0                           NAO_INFORMADA     0.0    Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0    Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0  SEM_ADICIONAL
# 3                           NAO_INFORMADA     0.0  SEM_ADICIONAL
# 4                Praça 56 do Estado Bahia   191.0        Apto 12
# 5      Rua 28 do Estado Rio Grande do Sul   805.0    Conjunto 13
# 6                  Rua 78 do Estado Goiás   877.0        Apto 14
# 7   Avenida 86 do Estado Distrito Federal   864.0        Apto 14
# 8                           NAO_INFORMADA     0.0  SEM_ADICIONAL
# 9   Avenida 54 do Estado Distrito Federal   889.0    Conjunto 14

# %%
#localizando se possui alguma linha  faltante

df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [cod, data_de_criação, nome, sobre_nome, gmail, num_contato, pais, estado, rua, numero, adicionais]
# Index: []

# %%
# VISUALIZANDO COM GRAFICOS

plt.rcParams['figure.figsize']=(13,8) # tamanho do grafico

tops = df['estado'].value_counts().head(6).index

q2=df[df['estado'].isin(tops)].groupby(['estado','estado']).size().unstack() #filtra e agrupa

q2= q2.loc[q2.sum(axis=1).sort_values(ascending=False).index]# ORDENA PELA SOMA TOTAL DOS ESTADOS (MAIOR PARA MENOR )

q2.plot(kind='bar',stacked = True)
plt.title('TOP 6 ESTADOS COM MAIS  FREQUENCIA  ')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(alpha=0.3,color='skyblue')
plt.xticks(rotation=45)
plt.show()

# %%
# FREQUENCIA COM OQ CADA ESTADO MAIS APARECEM
df['estado'].value_counts()
# Out:
# estado
# Pernambuco             8
# Rio Grande do Sul      6
# Maranhão               6
# Bahia                  6
# Mato Grosso            5
# Goiás                  5
# Ceará                  5
# Rio Grande do Norte    5
# São Paulo              4
# Acre                   4
# Rio de Janeiro         4
# NAO_INFORMADO          4
# Paraná                 4
# Minas Gerais           4
# Espírito Santo         4
# Mato Grosso do Sul     4
# Distrito Federal       3
# Santa Catarina         3
# Piauí                  3
# Alagoas                3
# Sergipe                2
# Amazonas               2
# Amapá                  2
# Roraima                2
# Rondônia               1
# Pará                   1
# Name: count, dtype: int64

# %%
plt.rcParams['figure.figsize']=(15,8) # tamanho do grafico

q10= df['estado'].value_counts().head(5)
q10 =q10.sort_values(ascending=False)

q10.plot(kind='bar',color='skyblue')
plt.title('TOP 5 COM MAIS FREQUENCIA')
plt.ylabel('QUANTIDADE')
plt.xlabel('ESTADOS')
plt.grid(color='black',alpha=0.4)
plt.xticks(rotation=45)
plt.show()
